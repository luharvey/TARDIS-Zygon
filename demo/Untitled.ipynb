# %%
# %matplotlib notebook
import zygon_dark as zygon

# %%
m = zygon.full_model()

# %%
m.import_full_profile('full_test_vels.dat')

# %%
m.plot()
# Out:
# <img src="data:image/png;base64,..." width="800">
